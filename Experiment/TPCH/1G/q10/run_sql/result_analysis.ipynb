# %%
import csv
import numpy as np
import pandas as pd

# %%
data = pd.read_csv(r"answer_sql10.csv", sep='|')
data[:4]
# Out:
#    c_custkey              c_name                          c_address  \
# 0        163  Customer#000000163                     OgrGcOnm4whd0f
# 1         70  Customer#000000070  mFowIuhnHjp2GjCiYYavkW kUwOjIaTCQ
# 2         70  Customer#000000070  mFowIuhnHjp2GjCiYYavkW kUwOjIaTCQ
# 3        208  Customer#000000208             Abye1MwcNfY0KO6yqv,Wwe
#
#    c_nationkey          c_phone  c_acctbal c_mktsegment  \
# 0           21  31-863-349-4121    2948.61    FURNITURE
# 1           22  32-828-107-2832    4867.52    FURNITURE
# 2           22  32-828-107-2832    4867.52    FURNITURE
# 3           19  29-859-139-6234    6239.89    MACHINERY
#
#                                            c_comment  o_orderkey  o_custkey  \
# 0    nag furiously furiously final requests. slyly s       29408        163
# 1  fter the special asymptotes. ideas after the u...       31653         70
# 2  fter the special asymptotes. ideas after the u...       31653         70
# ...

# %%
len(data)
# Out:
# 30910

# %% [markdown]
# ## relax

# %%
data1 = data[(data['c_mktsegment'] == "BUILDING") & (data['l_shipinstruct'] == "TAKE BACK RETURN") ]
print(len(data1))
# Out:
# 1571

# %%
data4 = data[(data['l_linenumber'] == 2)]
print(len(data4))
# Out:
# 6740

# %% [markdown]
# ## contract

# %%
data2 = data[(data['c_nationkey'] == 2)]
print(len(data2))
# Out:
# 1177

# %%
data1 = data[(data['l_shipinstruct'] == "DELIVER IN PERSON")]
print(len(data1))
# Out:
# 7656

# %%
data2 = data[(data['c_nationkey'] == 2)]
print(len(data2))

# %% [markdown]
# ## refinement

# %%
data1 = data[(data['c_nationkey'] == 12)]
print(len(data1))
# Out:
# 1334

# %%
data3 = data[(data['l_shipmode'] == "TRUCK")]
print(len(data3))
# Out:
# 4352

# %% [markdown]
# ## change date

# %%
s = data["o_orderdate"].values.tolist()
s.sort()
s
# Out:
# ['1994-11-29',
#  '1994-11-30',
#  '1994-11-30',
#  '1994-12-01',
#  '1994-12-02',
#  '1994-12-02',
#  '1994-12-02',
#  '1994-12-02',
#  '1994-12-03',
#  '1994-12-03',
#  '1994-12-04',
#  '1994-12-04',
#  '1994-12-04',
#  '1994-12-05',
#  '1994-12-05',
#  '1994-12-05',
#  '1994-12-05',
#  '1994-12-05',
#  '1994-12-06',
#  '1994-12-06',
#  '1994-12-06',
#  '1994-12-06',
#  '1994-12-06',
#  '1994-12-06',
#  '1994-12-07',
#  '1994-12-08',
#  '1994-12-08',
#  '1994-12-08',
#  '1994-12-09',
#  '1994-12-09',
#  '1994-12-09',
#  '1994-12-10',
#  '1994-12-10',
#  '1994-12-10',
#  '1994-12-10',
#  '1994-12-10',
#  '1994-12-11',
#  '1994-12-11',
#  '1994-12-11',
#  '1994-12-11',
#  '1994-12-11',
#  '1994-12-11',
#  '1994-12-11',
#  '1994-12-11',
#  '1994-12-11',
#  '1994-12-11',
#  '1994-12-11',
#  '1994-12-12',
#  '1994-12-12',
#  '1994-12-12',
#  '1994-12-12',
#  '1994-12-12',
#  '1994-12-12',
#  '1994-12-12',
#  '1994-12-12',
#  '1994-12-12',
#  '1994-12-12',
#  '1994-12-12',
# ...

# %%
s[-1]
# Out:
# '1995-03-27'
